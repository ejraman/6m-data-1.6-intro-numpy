# %% [markdown]
# <a href="https://colab.research.google.com/github/ejraman/6m-data-1.6-intro-numpy/blob/main/Lesson%201.6%20%E2%80%93%20NumPy%20for%20Beginners.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
  import numpy as np
np.__version__
# Out:
# '2.0.2'
